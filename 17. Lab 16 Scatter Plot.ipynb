# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Step 1: Load the dataset

# %%
df = pd.read_csv("Lab 13.csv")
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment                            RemoteWork   Check  \
# 0  Employed, full-time                                Remote  Apples
# 1  Employed, full-time                                Remote  Apples
# 2  Employed, full-time                                Remote  Apples
# 3   Student, full-time  Hybrid (some remote, some in-person)  Apples
# 4   Student, full-time  Hybrid (some remote, some in-person)  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# ...

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
new_df = df[["AgeNumeric", "JobSatPoints_6"]].dropna()

plt.figure(figsize=(10, 6))
sns.regplot(data=new_df, x="AgeNumeric", y="JobSatPoints_6", scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title("Gráfico de dispersión de Edad y Satisfacción laboral")
plt.xlabel("Edad")
plt.ylabel("Satisfacción laboral")
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
new_df = df[["ConvertedCompYearly", "JobSatPoints_6"]].dropna()

Q1 = df["ConvertedCompYearly"].quantile(0.25)
Q3 = df["ConvertedCompYearly"].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

new_df = df[(df["ConvertedCompYearly"] >= limite_inferior) & (df["ConvertedCompYearly"] <= limite_superior)]

plt.figure(figsize=(10, 6))
sns.regplot(data=new_df, x="ConvertedCompYearly", y="JobSatPoints_6", scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title("Gráfico de dispersión de Compensación anual y Satisfacción laboral")
plt.xlabel("Compensación anual")
plt.ylabel("Satisfacción laboral")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
new_df = df[["AgeNumeric", "JobSatPoints_6"]].dropna()

plt.figure(figsize=(10, 6))
sns.regplot(data=new_df, x="AgeNumeric", y="JobSatPoints_6", scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title("Gráfico de dispersión de Edad y Satisfacción laboral")
plt.xlabel("Edad")
plt.ylabel("Satisfacción laboral")
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
new_df = df[["AgeNumeric", "YearsCodePro"]].dropna()

plt.figure(figsize=(10, 6))
sns.regplot(data=new_df, x="AgeNumeric", y="YearsCodePro", scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title("Gráfico de dispersión de Edad y Experiencia laboral")
plt.xlabel("Edad")
plt.ylabel("Experiencia laboral")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
bubble_df = df[["ConvertedCompYearly", "JobSatPoints_6", "AgeNumeric"]].dropna()

Q1 = bubble_df["ConvertedCompYearly"].quantile(0.25)
Q3 = bubble_df["ConvertedCompYearly"].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

new_df = bubble_df[(bubble_df["ConvertedCompYearly"] >= limite_inferior) & (bubble_df["ConvertedCompYearly"] <= limite_superior)]

tamaño_burbujas = new_df["AgeNumeric"] * 10

plt.figure(figsize=(12, 7))
plt.scatter(new_df["ConvertedCompYearly"], new_df["JobSatPoints_6"], s=tamaño_burbujas, alpha=0.5, c=new_df["AgeNumeric"], cmap='viridis', edgecolors='w', linewidths=0.5)

plt.title("Gráfico de burbujas: Compensación anual vs Satisfacción laboral por Edad")
plt.xlabel("Compensación anual")
plt.ylabel("Satisfacción laboral")
plt.grid(True)
plt.colorbar(label='Edad')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
new_df = df[["LanguageHaveWorkedWith", "JobSatPoints_6"]].dropna()
new_df["LanguageHaveWorkedWith"] = new_df["LanguageHaveWorkedWith"].str.split(";")
X = new_df.explode("LanguageHaveWorkedWith")
X.rename(columns={"LanguageHaveWorkedWith": "Language"}, inplace=True)

Y = X.groupby("Language")["JobSatPoints_6"].mean().reset_index()
Z = X["Language"].value_counts().reset_index()
Z.columns = ["Language", "Count"]

lang_plot = pd.merge(Y, Z, on="Language")

plt.figure(figsize=(12, 7))
plt.scatter(lang_plot["Language"], lang_plot["JobSatPoints_6"], s=lang_plot["Count"], alpha=0.6, c='teal', edgecolors='w')

plt.title("Satisfacción laboral según lenguaje de programación")
plt.xlabel("Lenguaje de programación")
plt.ylabel("Satisfacción laboral promedio")
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
new_df = df[["ConvertedCompYearly", "JobSatPoints_6", "TipoEmpleoAgrupado"]].dropna()

Q1 = new_df["ConvertedCompYearly"].quantile(0.25)
Q3 = new_df["ConvertedCompYearly"].quantile(0.75)
IQR = Q3 - Q1
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

new_df = new_df[(new_df["ConvertedCompYearly"] >= limite_inferior) & (new_df["ConvertedCompYearly"] <= limite_superior)]

plt.figure(figsize=(12, 7))
sns.scatterplot(data=new_df, x="ConvertedCompYearly", y="JobSatPoints_6", hue="TipoEmpleoAgrupado", alpha=0.6, palette="tab10")

plt.title("Relación entre Compensación anual y Satisfacción laboral por tipo de empleo")
plt.xlabel("Compensación anual")
plt.ylabel("Satisfacción laboral")
plt.grid(True)
plt.legend(title="Tipo de empleo", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
new_df = df[["YearsCodePro", "Age", "AgeNumeric", "Country"]].dropna()

top_paises = new_df["Country"].value_counts().head(5).index
new_df = new_df[new_df["Country"].isin(top_paises)]

plt.figure(figsize=(12, 7))
sns.scatterplot(data=new_df, x="AgeNumeric", y="YearsCodePro", hue="Country", style="Age", palette="Set2", alpha=0.6)

plt.title("Experiencia laboral por edad y país")
plt.xlabel("Edad")
plt.ylabel("Años de experiencia profesional")
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
