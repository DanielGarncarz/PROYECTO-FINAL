# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Lab 10.csv")

df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment                            RemoteWork   Check  \
# 0  Employed, full-time                                Remote  Apples
# 1  Employed, full-time                                Remote  Apples
# 2  Employed, full-time                                Remote  Apples
# 3   Student, full-time  Hybrid (some remote, some in-person)  Apples
# 4   Student, full-time  Hybrid (some remote, some in-person)  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3  Hobby;Contribute to open-source projects;Other...
# 4  Hobby;Contribute to open-source projects;Other...
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ...  \
# 0  Technical documentation;Blogs;Written Tutorial...  ...
# 1  Technical documentation;Blogs;Books;Written Tu...  ...
# 2  Technical documentation;Blogs;Books;Written Tu...  ...
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...
# 4  Technical documentation;Blogs;Written Tutorial...  ...
#
#             SurveyLength SurveyEase  ConvertedCompYearly    JobSat  \
# 0  Appropriate in length       Easy              65000.0  6.969466
# 1  Appropriate in length       Easy              65000.0  6.969466
# 2  Appropriate in length       Easy              65000.0  6.969466
# 3               Too long       Easy              65000.0  6.969466
# 4              Too short       Easy              65000.0  6.969466
#
#   ConvertedCompYearly_MinMax ConvertedCompYearly_Zscore  \
# 0                   0.003998                  -0.067513
# 1                   0.003998                  -0.067513
# 2                   0.003998                  -0.067513
# 3                   0.003998                  -0.067513
# 4                   0.003998                  -0.067513
#
#   Log_ConvertedCompYearly ExperienceLevel ExperienceRange TipoEmpleoAgrupado
# 0               11.082158             Mid             0-5          Full time
# 1               11.082158          Expert           10-20          Full time
# 2               11.082158          Expert             20+          Full time
# 3               11.082158             Mid             0-5          Full time
# 4               11.082158             Mid             0-5          Full time
#
# [5 rows x 120 columns]

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
print(df.info())
print(df.dtypes)
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1248 entries, 0 to 1247
# Columns: 120 entries, ResponseId to TipoEmpleoAgrupado
# dtypes: float64(17), int64(1), object(102)
# memory usage: 1.1+ MB
# None
# ResponseId                      int64
# MainBranch                     object
# Age                            object
# Employment                     object
# RemoteWork                     object
#                                ...
# ConvertedCompYearly_Zscore    float64
# Log_ConvertedCompYearly       float64
# ExperienceLevel                object
# ExperienceRange                object
# TipoEmpleoAgrupado             object
# Length: 120, dtype: object
#         ResponseId  YearsCodePro     CompTotal      WorkExp  JobSatPoints_1  \
# count  1248.000000   1248.000000  1.247000e+03  1247.000000     1248.000000
# mean    624.500000     11.646493  1.145196e+08    12.824364       17.414603
# std     360.410877      9.332488  2.842329e+09     7.063465       17.259833
# min       1.000000      1.000000  0.000000e+00     0.000000        0.000000
# 25%     312.750000      3.000000  1.445000e+05    10.000000       10.000000
# 50%     624.500000     10.000000  4.366248e+07    12.050991       17.876307
# 75%     936.250000     17.000000  4.366248e+07    12.050991       17.876307
# max    1248.000000     50.000000  1.000000e+11    50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count     1247.000000     1247.000000     1247.000000     1247.000000
# mean         7.809361        9.334645       23.459384       21.214848
# std         13.487184       14.520630       17.918088       17.807544
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000       15.000000       10.000000
# 50%          8.241434       10.029729       24.178747       22.435310
# 75%          8.241434       10.029729       24.178747       22.435310
# max        100.000000      100.000000      100.000000      100.000000
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# count     1247.000000     1247.000000      1247.000000      1247.000000
# mean        19.138476       15.345214         9.851563         8.473168
# std         17.644503       17.241138        15.108966        13.472528
# min          0.000000        0.000000         0.000000         0.000000
# 25%         10.000000        5.000000         0.000000         0.000000
# 50%         19.961650       15.664058        10.629774         9.378726
# 75%         19.961650       15.664058        10.629774         9.378726
# max        100.000000      100.000000       100.000000       100.000000
#
#        ConvertedCompYearly       JobSat  ConvertedCompYearly_MinMax  \
# count          1247.000000  1248.000000                 1247.000000
# mean          78491.566961     6.960791                    0.004828
# std           58427.540267     1.592794                    0.003594
# min             127.000000     0.000000                    0.000008
# 25%           65000.000000     6.969466                    0.003998
# 50%           65000.000000     6.969466                    0.003998
# 75%           65000.000000     8.000000                    0.003998
# max         1000000.000000    10.000000                    0.061513
#
#        ConvertedCompYearly_Zscore  Log_ConvertedCompYearly
# count                 1247.000000              1247.000000
# mean                     0.052711                11.062458
# std                      0.520649                 0.807245
# min                     -0.645597                 4.852030
# 25%                     -0.067513                11.082158
# 50%                     -0.067513                11.082158
# 75%                     -0.067513                11.082158
# max                      8.264285                13.815512

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
for columna in df.columns:
    if df[columna].isnull().any():
        if df[columna].dtype == 'object':
            moda = df[columna].mode()[0]
            df[columna] = df[columna].fillna(moda)
        elif pd.api.types.is_numeric_dtype(df[columna]):
            media = df[columna].mean()
            df[columna] = df[columna].fillna(media)

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
df['JobSat'] = df['JobSat'].round()

# %%
print("Distribución de Employment:")
print(df['TipoEmpleoAgrupado'].value_counts().head())

print("\nDistribución de Job Satisfaction:")
print(df['JobSat'].value_counts().head())

print("\nDistribución de Años de Experiencia Profesional:")
print(df['ExperienceRange'].value_counts().head())
# Out:
# Distribución de Employment:
# TipoEmpleoAgrupado
# Full time                                 917
# Independent/Freelancer                    147
# Not employed, but looking for work         79
# Part time                                  35
# Not employed, and not looking for work     26
# Name: count, dtype: int64
#
# Distribución de Job Satisfaction:
# JobSat
# 7.0     719
# 8.0     170
# 9.0      89
# 6.0      88
# 10.0     58
# Name: count, dtype: int64
#
# Distribución de Años de Experiencia Profesional:
# ExperienceRange
# 10-20    372
# 0-5      369
# 20+      259
# 5-10     248
# Name: count, dtype: int64

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
X = df['JobSat'].value_counts(dropna=False)

# %%
plt.figure(figsize=(8,6))
plt.pie(X, labels= X.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Distribution of Job Satisfaction")
plt.axis('equal')
plt.show()

# %%
### El GRÁFICO MUESTRA QUE EN LINEAS GENEREALES LA SATISFACCIÓN LABORAL DE LOS ENCUESTADOS ES POSITIVA DADO QUE LA GRAN MAYORÍA DE LOS ENCUESTADOS ASIGNARON UNA VALORACIÓN DE ENTRE 6 Y 8 PUNTOS EN ESTA CATEGORÍA.
### LOS ENCUESTADOS QUE MOSTRARON UNA BAJA SATISFACCIÓN LABORAL (ENTRE 0 Y 5) REPRESENTAN UNA BAJA PROPORCIÓN SOBRE EL TOTAL.

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
HaveWorked = df["LanguageHaveWorkedWith"].str.split(";").explode()
WantToWork = df["LanguageWantToWorkWith"].str.split(";").explode()
HaveWorked_counts = HaveWorked.value_counts()
WantToWork_counts = WantToWork.value_counts()

Comparative = pd.concat([HaveWorked_counts, WantToWork_counts], axis=1, keys=['HaveWorkedWith', 'WantToWorkWith']).fillna(0)


Comparative.head(10).plot(kind='bar', figsize=(14,6))
plt.title('Comparación de lenguajes: Trabajado vs Querer Trabajar')
plt.ylabel('Cantidad de respuestas')
plt.xticks(rotation=90)
plt.legend(["Trabajado con", "Quiere trabajar con"])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
new_df = df[["RemoteWork","Country"]]
country_counts = new_df["Country"].value_counts()
country_counts.head(10)
# Out:
# Country
# United States of America                                327
# United Kingdom of Great Britain and Northern Ireland    102
# Germany                                                  91
# India                                                    66
# France                                                   52
# Ukraine                                                  44
# Italy                                                    43
# Canada                                                   31
# Netherlands                                              27
# Poland                                                   26
# Name: count, dtype: int64

# %%
new_df = df[["RemoteWork","Country"]]
country_counts = new_df["Country"].value_counts()
top_countries = country_counts[country_counts > 20].index
new_df_top = new_df[new_df["Country"].isin(top_countries)]
data = pd.crosstab(new_df_top["Country"],new_df_top["RemoteWork"])

plt.figure(figsize=(16,10))
sns.heatmap(data,annot=True, fmt='d', cmap="YlGnBu")
plt.title("Distribución de trabajo remoto por país")
plt.xlabel("Trabajo remoto")
plt.ylabel("País")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
# !pip install spicy
from scipy.stats import pearsonr
# Out:
# Collecting spicy
#   Downloading spicy-0.16.0-py2.py3-none-any.whl.metadata (310 bytes)
# Collecting scipy (from spicy)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /opt/conda/lib/python3.12/site-packages (from scipy->spicy) (2.2.5)
# Downloading spicy-0.16.0-py2.py3-none-any.whl (1.7 kB)
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 168.7 MB/s eta 0:00:0000:01
# Installing collected packages: scipy, spicy
# Successfully installed scipy-1.15.3 spicy-0.16.0

# %%
df["YearsCodePro"].replace('Less than 1 year', 0, inplace=True)
df["YearsCodePro"].replace('More than 50 years', 50, inplace=True)

df["YearsCodePro"] = df["YearsCodePro"].astype(float)

new_df = df[["JobSat", "YearsCodePro"]].copy()

new_df["JobSat"] = pd.to_numeric(new_df["JobSat"], errors='coerce')

new_df = new_df.dropna()

pearson_corr, _ = pearsonr(new_df["JobSat"], new_df["YearsCodePro"])
print("Correlación de Pearson:", round(pearson_corr, 3))

plt.figure(figsize=(8,6))
sns.regplot(x='YearsCodePro', y='JobSat', data=new_df, line_kws={'color':'red'})
plt.title('Relación entre Años de Experiencia y Satisfacción Laboral')
plt.xlabel('Años de Experiencia Profesional (YearsCodePro)')
plt.ylabel('Satisfacción Laboral (JobSat)')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_912/1907647612.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["YearsCodePro"].replace('Less than 1 year', 0, inplace=True)
# /tmp/ipykernel_912/1907647612.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["YearsCodePro"].replace('More than 50 years', 50, inplace=True)
# Correlación de Pearson: 0.074

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
crosstab = pd.crosstab(df['EdLevel'], df['TipoEmpleoAgrupado'])

crosstab.head()

crosstab.plot(kind='bar', stacked=True, figsize=(12,8), colormap='tab20')

plt.title('Relación entre Nivel de Educación y Estado Laboral')
plt.xlabel('Nivel de Educación')
plt.ylabel('Cantidad de Personas')
plt.legend(title='Estado Laboral', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
df.to_csv('Lab 11', index=False)

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
